# %% [markdown]
# <a href="https://colab.research.google.com/github/aaaraafaat/Data-Science/blob/main/Bioinformetics_Gene_Felis_Catus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/aaaraafaat/Data-Science/refs/heads/main/Cat%20ncbi_dataset.csv')

# %%
df
# Out:
#             Accession   Begin     End Chromosome Orientation  \
# 0         NC_001700.1     866     935         MT        plus
# 1         NC_001700.1     936    1895         MT        plus
# 2         NC_001700.1    1896    1963         MT        plus
# 3         NC_001700.1    1964    3537         MT        plus
# 4         NC_001700.1    3538    3612         MT        plus
# ...               ...     ...     ...        ...         ...
# 39399  NW_025408545.1   56337  100115        NaN       minus
# 39400  NW_025408546.1    6100   25045        NaN       minus
# 39401  NW_025408547.1   81145   83397        NaN       minus
# 39402  NW_025408547.1   83422  118138        NaN        plus
# 39403  NW_025408547.1  117102  118091        NaN       minus
#
#                                                     Name        Symbol  \
# 0                                               tRNA-Phe           NaN
# 1                                                 s-rRNA           NaN
# ...

# %%
df.Orientation.value_counts()
# Out:
# Orientation
# plus     19769
# minus    19635
# Name: count, dtype: int64

# %%
df['Gene Type'].value_counts()
# Out:
# Gene Type
# protein-coding            20453
# lncRNA                    12557
# pseudogene                 3619
# snRNA                      1124
# tRNA                        763
# snoRNA                      589
# other                       131
# V_segment                    83
# rRNA                         44
# misc_RNA                     26
# C_region                     14
# transcribed_pseudogene        1
# Name: count, dtype: int64
